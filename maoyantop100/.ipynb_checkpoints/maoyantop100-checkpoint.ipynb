# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import pandas as pd

# %%
url = 'https://maoyan.com/board/4'

headers = {'user-agent':'Mozilla/5.0'}
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')

#单个影片解析
movie_lists = soup.select('.board-wrapper dd a')[0] #0,1表示第一个电影
movie_name = soup.select('.board-wrapper dd a')[0]['title']
stars = soup.select('.board-wrapper .star')[0].text.lstrip('\n                主演：').rstrip('\n ')
release_time = soup.select('.board-wrapper .releasetime')[0].text.split('上映时间：')[-1].split('(')[0]
release_place = soup.select('.board-wrapper .releasetime')[0].text.split('上映时间：')[-1].split('(')[-1].split(')')[0]
rank = soup.select('.board-wrapper dd i')[0].text
score = soup.select('.board-wrapper dd i')[1].text + soup.select('.board-wrapper dd i')[2].text
image_link = soup.select('.board-wrapper dd img')[1]["data-src"] #0,1,2表示第一步影片

# %%
movie_info = {}
# movie_info['movie_lists'] = movie_lists 
movie_info['movie_name'] = movie_name #电影名字
movie_info['stars'] = stars #主演
movie_info['release_time'] = release_time #上映时间
movie_info['release_place'] = release_place #上映地点
movie_info['rank'] = rank #排名
movie_info['score'] = score #得分
movie_info['image_link'] = image_link #海报图片链接

# %%
index = list(range(0,20,2)) #遍历每一页中的每个电影
movies = [] #列表中的每一个元素存储了一个字典，字典中包含了一部电影信息
for i in index:
    movie_info = {}
    #1电影名字
    movie_name =  soup.select('.board-wrapper dd a')[i]['title']
    #2主演
    stars = soup.select('.board-wrapper .star')[int(i/2)].text.lstrip('\n                主演：').rstrip('\n ')
    #3上映时间
    release_time = soup.select('.board-wrapper .releasetime')[int(i/2)] \
    .text.split('上映时间：')[-1].split('(')[0]
    #4上映地点
    release_place = soup.select('.board-wrapper .releasetime')[int(i/2)] \
    .text.split('上映时间：')[-1].split('(')[-1].split(')')[0]
    #5排名
    rank = soup.select('.board-wrapper dd i')[int(i/2*3)].text
    #6得分
    score = soup.select('.board-wrapper dd i')[int(i/2*3)+1].text + \
    soup.select('.board-wrapper dd i')[int(i/2*3)+2].text
    #7海报图片链接
    image_link = soup.select('.board-wrapper dd img')[i+1]["data-src"] #0,1,2表示第一步影片
    
    movie_info['movie_name'] = movie_name #电影名字
    movie_info['stars'] = stars #主演
    movie_info['release_time'] = release_time #上映时间
    movie_info['release_place'] = release_place #上映地点
    movie_info['rank'] = rank #排名
    movie_info['score'] = score #得分
    movie_info['image_link'] = image_link #海报图片链接
    movies.append(movie_info)

# %%
type(release_time)
# Out:
# str

# %% [markdown]
# ## 1.用BeautifulSoup解析一页中的电影信息

# %%
def get_one_page_soup(url):
    '''
    Desc:
        用BeautifulSoup解析一页中的电影信息，并返回单页的soup信息
    param:
        url -- 单页的链接地址
    return:
        soup -- 用BeautifulSoup解析的单页的内容
    '''
    headers = {'user-agent':'Mozilla/5.0'}
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    return soup

# %% [markdown]
# ## 2.解析一页中的电影信息

# %%
def one_page_parser(soup):
    '''
    Desc:
        用于解析单页的电影信息内容，并返回一个电影信息列表
    param:
        soup -- 用BeautifulSoup解析的单页的内容
    return:
        movies -- 单页的电影信息列表，列表中的每一个元素存储了一个字典，字典中包含了一部电影信息
    '''
    index = list(range(0,20,2)) #遍历每一页中的每个电影
    movies = [] #列表中的每一个元素存储了一个字典，字典中包含了一部电影信息
    for i in index:
        movie_info = {}
        #1电影名字
        movie_name =  soup.select('.board-wrapper dd a')[i]['title']
        #2主演
        stars = soup.select('.board-wrapper .star')[int(i/2)].text.lstrip('\n                主演：').rstrip('\n ')
        #3上映时间
        release_time = soup.select('.board-wrapper .releasetime')[int(i/2)] \
        .text.split('上映时间：')[-1].split('(')[0]
        #4上映地点
        release_place = soup.select('.board-wrapper .releasetime')[int(i/2)] \
        .text.split('上映时间：')[-1].split('(')[-1].split(')')[0]
        #5排名
        rank = soup.select('.board-wrapper dd i')[int(i/2*3)].text
        #6得分
        score = soup.select('.board-wrapper dd i')[int(i/2*3)+1].text + \
        soup.select('.board-wrapper dd i')[int(i/2*3)+2].text
        #7海报图片链接
        image_link = soup.select('.board-wrapper dd img')[i+1]["data-src"] #0,1,2表示第一步影片

        movie_info['movie_name'] = movie_name #电影名字
        movie_info['stars'] = stars #主演
        movie_info['release_time'] = release_time #上映时间
        movie_info['release_place'] = release_place #上映地点
        movie_info['rank'] = rank #排名
        movie_info['score'] = score #得分
        movie_info['image_link'] = image_link #海报图片链接
        movies.append(movie_info)
    return movies

# %% [markdown]
# ## 3.将单页的电影信息保存到本地的json格式中

# %%
def write_to_file(movies_list):
    '''
    Desc:
        将单页的电影信息列表存储为json格式
    param:
        movies_list -- 单页的电影信息列表
    '''
    file_name = 'movies.json'
    with open(file_name, 'a', encoding='utf-8') as f:
        json.dump(movies_list, f, ensure_ascii=False)

# %%
url = 'https://maoyan.com/board/4'
soup = get_one_page_soup(url)
movies_list = one_page_parser(soup)
write_to_file(movies_list)

# %% [markdown]
# ## 4.改变每页的offset参数进行多页的抓取

# %%
movies_lists = []
for i in range(10):
    url = 'https://maoyan.com/board/4?offset=' + str(i*10) #总共10页，构建每一页的url
    soup = get_one_page_soup(url)
    movies_list = one_page_parser(soup)
    movies_lists.extend(movies_list)
    write_to_file(movies_list)

# %%
##3.使用pandas整理数据
df = pd.DataFrame(movies_lists)

# %%
df
# Out:
#                                            image_link     movie_name rank  \
# 0   http://p1.meituan.net/movie/20803f59291c47e1e1...           霸王别姬    1
# 1   http://p0.meituan.net/movie/283292171619cdfd5b...         肖申克的救赎    2
# 2   http://p0.meituan.net/movie/54617769d96807e4d8...           罗马假日    3
# 3   http://p0.meituan.net/movie/e55ec5d18ccc83ba7d...        这个杀手不太冷    4
# 4   http://p1.meituan.net/movie/f5a924f362f050881f...             教父    5
# 5   http://p1.meituan.net/movie/0699ac97c82cf01638...          泰坦尼克号    6
# 6   http://p0.meituan.net/movie/b03e9c52c585635d2c...             龙猫    7
# 7   http://p0.meituan.net/movie/da64660f82b98cdc1b...         唐伯虎点秋香    8
# 8   http://p0.meituan.net/movie/b076ce63e9860ecf1e...           千与千寻    9
# 9   http://p0.meituan.net/movie/46c29a8b8d8424bdda...           魂断蓝桥   10
# 10  http://p0.meituan.net/movie/230e71d398e0c54730...           乱世佳人   11
# 11  http://p1.meituan.net/movie/18e3191039d5e71562...           喜剧之王   12
# 12  http://p1.meituan.net/movie/ba1ed511668402605e...           天空之城   13
# 13  http://p1.meituan.net/movie/14a7b337e8063e3ce0...           大闹天宫   14
# 14  http://p1.meituan.net/movie/39ed7a0941a3604bba...         辛德勒的名单   15
# 15  http://p1.meituan.net/movie/6bc004d57358ee6875...           音乐之声   16
# 16  http://p0.meituan.net/movie/ae7245920d95c03765...           春光乍泄   17
# 17  http://p1.meituan.net/movie/0e91ffcfa7e5344921...         剪刀手爱德华   18
# 18  http://p0.meituan.net/movie/43d259ecbcd53e8bbe...           美丽人生   19
# 19  http://p1.meituan.net/movie/c15b7623cce2f51c75...          海上钢琴师   20
# 20  http://p1.meituan.net/movie/d981a12f59d3cc92ff...           黑客帝国   21
# 21  http://p0.meituan.net/movie/932bdfbef5be3543e6...      指环王3：王者无敌   22
# 22  http://p1.meituan.net/movie/b449893ebc63d5c54e...          加勒比海盗   23
# 23  http://p1.meituan.net/movie/aacb9ed2a6601bfe51...      哈利·波特与魔法石   24
# 24  http://p0.meituan.net/movie/d12a1c198ad9ffac72...       蝙蝠侠：黑暗骑士   25
# 25  http://p0.meituan.net/movie/8959888ee0c399b0fe...          楚门的世界   26
# 26  http://p1.meituan.net/movie/53b6f0b66882a53b08...     射雕英雄传之东成西就   27
# 27  http://p1.meituan.net/movie/0d93b5b585ce29c668...            无间道   28
# 28  http://p0.meituan.net/movie/5cfa597a98b35ee4ee...      指环王2：双塔奇兵   29
# 29  http://p1.meituan.net/movie/4592eef6b6dffcd1d9...         机器人总动员   30
# ..                                                ...            ...  ...
# 70  http://p1.meituan.net/movie/68fa7db99e958c47d7...  哈利·波特与死亡圣器（下）   71
# 71  http://p1.meituan.net/movie/7ed07b8ea8c0e0d0c7...         初恋这件小事   72
# 72  http://p0.meituan.net/movie/9e9f12cfc1f54c973d...          新龙门客栈   73
# 73  http://p1.meituan.net/movie/8ad5a0f521fb15637d...            甜蜜蜜   74
# 74  http://p0.meituan.net/movie/7874ba1378033b0b49...           触不可及   75
# 75  http://p0.meituan.net/movie/40/9791315.jpg@160...             熔炉   76
# 76  http://p1.meituan.net/movie/dc2246233a6f5ac1e3...      大话西游之大圣娶亲   77
# 77  http://p1.meituan.net/movie/bc7b6ababa54e11577...            小鞋子   78
# 78  http://p0.meituan.net/movie/4cc4c55c29b77b0904...             素媛   79
# 79  http://p0.meituan.net/movie/5420be40e3b755ffe0...           萤火之森   80
# 80  http://p0.meituan.net/movie/3985eaf3858bea0f2a...           窃听风暴   81
# 81  http://p1.meituan.net/movie/a0e0426a4390f5ecb4...       穿条纹睡衣的男孩   82
# 82  http://p0.meituan.net/movie/4abc8c932cfacfc008...          时空恋旅人   83
# 83  http://p0.meituan.net/movie/ce262f261f69fc3d67...     借东西的小人阿莉埃蒂   84
# 84  http://p1.meituan.net/movie/6a6e74b2c289f9fa44...         7号房的礼物   85
# 85  http://p0.meituan.net/movie/7373dbba07b50ce6f2...            海豚湾   86
# 86  http://p0.meituan.net/movie/b5ff0216e689b3fcc0...           恐怖直播   87
# 87  http://p1.meituan.net/movie/c835b3588d0061ed3b...         忠犬八公物语   88
# 88  http://p1.meituan.net/movie/b553d13f30100db731...           上帝之城   89
# 89  http://p0.meituan.net/movie/8fabf3894b7d12d3d2...            辩护人   90
# 90  http://p1.meituan.net/movie/73349facab53529ab9...            七武士   91
# 91  http://p1.meituan.net/movie/30310858fdab34c7a1...          完美的世界   92
# 92  http://p1.meituan.net/movie/2c0a5fedf4b43d1421...             一一   93
# 93  http://p0.meituan.net/movie/0018b57299d0d45403...             海洋   94
# 94  http://p1.meituan.net/movie/36a893c53a13f9bb93...           爱·回家   95
# 95  http://p1.meituan.net/movie/9bff56ed3ea38bb182...          黄金三镖客   96
# 96  http://p1.meituan.net/movie/ed50b58bf636d207c5...            我爱你   97
# 97  http://p1.meituan.net/movie/a1634f4e49c8517ae0...           迁徙的鸟   98
# 98  http://p0.meituan.net/movie/885fc379c614a2b417...           阿飞正传   99
# 99  http://p0.meituan.net/movie/3e5f5f3aa4b7e55765...           英雄本色  100
#
#    release_place release_time score                                    stars
# 0           中国香港   1993-01-01   9.6                               张国荣,张丰毅,巩俐
# 1             美国   1994-10-14   9.5                      蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿
# 2             美国   1953-09-02   9.1                    格利高里·派克,奥黛丽·赫本,埃迪·艾伯特
# 3             法国   1994-09-14   9.5                      让·雷诺,加里·奥德曼,娜塔莉·波特曼
# 4             美国   1972-03-24   9.3                     马龙·白兰度,阿尔·帕西诺,詹姆斯·肯恩
# 5     1998-04-03   1998-04-03   9.5                 莱昂纳多·迪卡普里奥,凯特·温丝莱特,比利·赞恩
# 6             日本   1988-04-16   9.2                           日高法子,坂本千夏,糸井重里
# 7           中国香港   1993-07-01   9.2                               周星驰,巩俐,郑佩佩
# 8             日本   2001-07-20   9.3                            柊瑠美,入野自由,夏木真理
# 9             美国   1940-05-17   9.2                      费雯·丽,罗伯特·泰勒,露塞尔·沃特森
# 10            美国   1939-12-15   9.1                    费雯·丽,克拉克·盖博,奥利维娅·德哈维兰
# 11          中国香港   1999-02-13   9.2                              周星驰,莫文蔚,张柏芝
# 12          1992         1992   9.1                           寺田农,鹫尾真知子,龟山助清
# 13    1965-12-31   1965-12-31   9.0                               邱岳峰,毕克,富润生
# 14            美国   1993-12-15   9.2                      连姆·尼森,拉尔夫·费因斯,本·金斯利
# 15            美国   1965-03-02   9.0                 朱莉·安德鲁斯,克里斯托弗·普卢默,埃琳诺·帕克
# 16          中国香港   1997-05-30   9.2                               张国荣,梁朝伟,张震
# 17            美国   1990-12-06   8.8                     约翰尼·德普,薇诺娜·瑞德,黛安·韦斯特
# 18           意大利   1997-12-20   9.3                罗伯托·贝尼尼,尼可莱塔·布拉斯基,乔治·坎塔里尼
# 19           意大利   1998-10-28   9.2                    蒂姆·罗斯,普路特·泰勒·文斯,比尔·努恩
# 20    2000-01-14   2000-01-14   9.0                  基努·里维斯,凯瑞-安·莫斯,劳伦斯·菲什伯恩
# 21    2004-03-15   2004-03-15   9.2                     伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒
# 22    2003-11-21   2003-11-21   8.9                    约翰尼·德普,凯拉·奈特莉,奥兰多·布鲁姆
# 23    2002-01-26   2002-01-26   9.1                  丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃森
# 24            美国   2008-07-18   9.3                   克里斯蒂安·贝尔,希斯·莱杰,艾伦·艾克哈特
# 25            美国   1998-06-01   8.9                       金·凯瑞,劳拉·琳妮,诺亚·艾默里奇
# 26          中国香港   1993-02-05   8.9                              张国荣,梁朝伟,张学友
# 27    2003-09-05   2003-09-05   9.1                              刘德华,梁朝伟,黄秋生
# 28    2003-04-25   2003-04-25   9.1                     伊莱贾·伍德,伊恩·麦克莱恩,丽芙·泰勒
# 29            美国   2008-06-27   9.3                      本·贝尔特,艾丽莎·奈特,杰夫·格尔林
# ..           ...          ...   ...                                      ...
# 70    2011-08-04   2011-08-04   9.0                  丹尼尔·雷德克里夫,鲁伯特·格林特,艾玛·沃森
# 71    2012-06-05   2012-06-05   8.8            马里奥·毛瑞尔,平采娜·乐维瑟派布恩,阿查拉那·阿瑞亚卫考
# 72    2012-02-24   2012-02-24   8.8                              张曼玉,梁家辉,甄子丹
# 73    2015-02-13   2015-02-13   9.2                               黎明,张曼玉,曾志伟
# 74            法国   2011-11-02   9.1                      弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼
# 75            韩国   2011-09-22   8.8                               孔刘,郑有美,金智英
# 76    2014-10-24   2014-10-24   8.8                               周星驰,朱茵,莫文蔚
# 77            美国   1999-01-22   9.1  默罕默德·阿米尔·纳吉,Kamal Mirkarimi,Behzad Rafi
# 78            韩国   2013-10-02   9.1                               李来,薛耿求,严志媛
# 79            日本   2011-09-17   9.0                           内山昂辉,佐仓绫音,后藤弘树
# 80            德国   2006-03-23   9.0                 乌尔里希·穆埃,塞巴斯蒂安·科赫,马蒂娜·格德克
# 81            英国   2008-09-12   9.0                   阿萨·巴特菲尔德,维拉·法米加,大卫·休里斯
# 82            英国   2013-09-04   8.9                  瑞秋·麦克亚当斯,多姆纳尔·格里森,比尔·奈伊
# 83            日本   2010-07-17   8.8                           志田未来,神木隆之介,大竹忍
# 84            韩国   2013-01-23   8.9                              柳承龙,郑镇荣,朴信惠
# 85            美国   2009-07-31   8.9                     里克·奥巴瑞,路易·西霍尤斯,哈迪·琼斯
# 86            韩国   2013-07-31   8.8                              河正宇,李璟荣,李大为
# 87            日本   1987-08-01   9.0                          仲代达矢,春川真澄,井川比佐志
# 88            巴西   2002-08-30   8.9            亚历桑德雷·罗德里格斯,艾莉丝·布拉加,莱安德鲁·菲尔米诺
# 89            韩国   2013-12-18   8.8                              宋康昊,郭度沅,吴达洙
# 90            日本   1954-04-26   9.1                             三船敏郎,志村乔,千秋实
# 91            美国   1993-11-24   8.9                 凯文·科斯特纳,克林特·伊斯特伍德,T·J·劳瑟
# 92            法国   2000-09-20   8.9                              吴念真,金燕玲,李凯莉
# 93    2011-08-12   2011-08-12   9.0                         雅克·贝汉,姜文,兰斯洛特·贝汉
# 94            韩国   2002-04-05   9.0                              俞承豪,金艺芬,童孝熙
# 95           意大利   1966-12-23   8.9                 克林特·伊斯特伍德,李·范·克里夫,埃里·瓦拉赫
# 96            韩国   2011-02-17   9.0                              宋在浩,李顺才,尹秀晶
# 97            法国   2001-12-12   9.1                     雅克·贝汉,Philippe Labro
# 98    2018-06-25   2018-06-25   8.8                              张国荣,张曼玉,刘德华
# 99    2017-11-17   2017-11-17   9.2                               狄龙,张国荣,周润发
#
# [100 rows x 7 columns]
